# %% [markdown]
# <a href="https://colab.research.google.com/github/athenalobo/Music/blob/main/HMM_music_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install hmmlearn
# Out:
# ...
#      |████████████████████████████████| 374 kB 5.0 MB/s
# ...

# %%
from hmmlearn import hmm

# %%
startprob = np.array([0.6, 0.3, 0.1, 0.0])
transmat = np.array([[0.7, 0.2, 0.0, 0.1],
                     [0.3, 0.5, 0.2, 0.0],
                     [0.0, 0.3, 0.5, 0.2],
                     [0.2, 0.0, 0.2, 0.6]])
means = np.array([[0.0,  0.0],
                  [0.0, 11.0],
                  [9.0, 10.0],
                  [11.0, -1.0]])
covars = .5 * np.tile(np.identity(2), (4, 1, 1))

# %% [markdown]
# Preparing parameters for 4 components HMM

# %% [markdown]
# Build an HMM instance and set parameters

# %%
model = hmm.GaussianHMM(n_components=4, covariance_type="full")

# %%
model.startprob_ = startprob
model.transmat_ = transmat
model.means_ = means
model.covars_ = covars

# %% [markdown]
# Generating samples

# %%
X, Z = model.sample(500)

# %% [markdown]
# Plotting the sampled data

# %%
plt.plot(X[:, 0], X[:, 1], ".-", label="observations", ms=6,
         mfc="orange",alpha=0.7)

# %% [markdown]
# Indicate the component numbers

# %%
for i, m in enumerate(means):
    plt.text(m[0], m[1], 'Component %i' % (i + 1),
             size=10, horizontalalignment='center',
             bbox=dict(alpha=0.7, facecolor='red'))
plt.legend(loc='best')
plt.plot(X[:, 0], X[:, 1], ".-", label="observations", ms=6,
         mfc="orange",alpha=0.7)
plt.show()
# Out:
# No handles with labels found to put in legend.
